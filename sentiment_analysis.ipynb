# %%
import pandas as pd

books = pd.read_csv("books_with_categories.csv")

# %%
from transformers import pipeline
classifier = pipeline("text-classification",
                      model="j-hartmann/emotion-english-distilroberta-base",
                      top_k= None,
                      device="cpu")
classifier("I love this!")
# Out:
# /Users/tariqahmad/PycharmProjects/BookRecommenderProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [[{'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'surprise', 'score': 0.008528688922524452},
#   {'label': 'neutral', 'score': 0.00576459476724267},
#   {'label': 'anger', 'score': 0.004419790115207434},
#   {'label': 'sadness', 'score': 0.0020923931151628494},
#   {'label': 'disgust', 'score': 0.001611992483958602},
#   {'label': 'fear', 'score': 0.00041385277290828526}]]

# %%
books["description"][0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
classifier(books["description"][0])
# Out:
# [[{'label': 'fear', 'score': 0.6548404693603516},
#   {'label': 'neutral', 'score': 0.16985225677490234},
#   {'label': 'sadness', 'score': 0.11640916764736176},
#   {'label': 'surprise', 'score': 0.020700691267848015},
#   {'label': 'disgust', 'score': 0.019100693985819817},
#   {'label': 'joy', 'score': 0.015161451883614063},
#   {'label': 'anger', 'score': 0.003935145679861307}]]

# %%
classifier(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296019196510315},
#   {'label': 'neutral', 'score': 0.14038589596748352},
#   {'label': 'fear', 'score': 0.06816241145133972},
#   {'label': 'joy', 'score': 0.04794280603528023},
#   {'label': 'anger', 'score': 0.009156368672847748},
#   {'label': 'disgust', 'score': 0.002628478454425931},
#   {'label': 'sadness', 'score': 0.0021221672650426626}],
#  [{'label': 'neutral', 'score': 0.4493703842163086},
#   {'label': 'disgust', 'score': 0.27359122037887573},
#   {'label': 'joy', 'score': 0.10908333957195282},
#   {'label': 'sadness', 'score': 0.09362752735614777},
#   {'label': 'anger', 'score': 0.040478311479091644},
#   {'label': 'surprise', 'score': 0.02697012946009636},
#   {'label': 'fear', 'score': 0.006879054941236973}],
#  [{'label': 'neutral', 'score': 0.6462147235870361},
#   {'label': 'sadness', 'score': 0.24273446202278137},
#   {'label': 'disgust', 'score': 0.04342271015048027},
#   {'label': 'surprise', 'score': 0.028300544247031212},
#   {'label': 'joy', 'score': 0.014211485162377357},
#   {'label': 'fear', 'score': 0.014084108173847198},
#   {'label': 'anger', 'score': 0.011031895875930786}],
#  [{'label': 'fear', 'score': 0.928168535232544},
#   {'label': 'anger', 'score': 0.0321907214820385},
#   {'label': 'neutral', 'score': 0.012808626517653465},
#   {'label': 'sadness', 'score': 0.008756839670240879},
#   {'label': 'surprise', 'score': 0.008597870357334614},
#   {'label': 'disgust', 'score': 0.008431773632764816},
#   {'label': 'joy', 'score': 0.0010455811861902475}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104142017662525},
#   {'label': 'disgust', 'score': 0.00648059556260705},
#   {'label': 'fear', 'score': 0.005393985193222761},
#   {'label': 'surprise', 'score': 0.002286937553435564},
#   {'label': 'anger', 'score': 0.0018428885377943516},
#   {'label': 'joy', 'score': 0.0017338788602501154}],
#  [{'label': 'joy', 'score': 0.932797908782959},
#   {'label': 'disgust', 'score': 0.03771715238690376},
#   {'label': 'neutral', 'score': 0.01589186117053032},
#   {'label': 'sadness', 'score': 0.006444504950195551},
#   {'label': 'anger', 'score': 0.00502497935667634},
#   {'label': 'surprise', 'score': 0.0015812070341780782},
#   {'label': 'fear', 'score': 0.0005423061084002256}],
#  [{'label': 'joy', 'score': 0.652871310710907},
#   {'label': 'neutral', 'score': 0.25427427887916565},
#   {'label': 'surprise', 'score': 0.06808299571275711},
#   {'label': 'sadness', 'score': 0.009908992797136307},
#   {'label': 'disgust', 'score': 0.00651220278814435},
#   {'label': 'anger', 'score': 0.004821298643946648},
#   {'label': 'fear', 'score': 0.0035290131345391273}],
#  [{'label': 'neutral', 'score': 0.5494758486747742},
#   {'label': 'sadness', 'score': 0.11169032752513885},
#   {'label': 'disgust', 'score': 0.10400691628456116},
#   {'label': 'surprise', 'score': 0.0787656232714653},
#   {'label': 'anger', 'score': 0.06413383036851883},
#   {'label': 'fear', 'score': 0.05136294662952423},
#   {'label': 'joy', 'score': 0.04056455194950104}]]

# %%
sentences = books["description"][0].split(".")
predictions = classifier(sentences)

# %%
sentences[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives'

# %%
predictions[0]
# Out:
# [{'label': 'surprise', 'score': 0.7296019196510315},
#  {'label': 'neutral', 'score': 0.14038589596748352},
#  {'label': 'fear', 'score': 0.06816241145133972},
#  {'label': 'joy', 'score': 0.04794280603528023},
#  {'label': 'anger', 'score': 0.009156368672847748},
#  {'label': 'disgust', 'score': 0.002628478454425931},
#  {'label': 'sadness', 'score': 0.0021221672650426626}]

# %%
sentences[3]
# Out:
# ' Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist'

# %%
predictions[3]
# Out:
# [{'label': 'fear', 'score': 0.928168535232544},
#  {'label': 'anger', 'score': 0.0321907214820385},
#  {'label': 'neutral', 'score': 0.012808626517653465},
#  {'label': 'sadness', 'score': 0.008756839670240879},
#  {'label': 'surprise', 'score': 0.008597870357334614},
#  {'label': 'disgust', 'score': 0.008431773632764816},
#  {'label': 'joy', 'score': 0.0010455811861902475}]

# %%
predictions
# Out:
# [[{'label': 'surprise', 'score': 0.7296019196510315},
#   {'label': 'neutral', 'score': 0.14038589596748352},
#   {'label': 'fear', 'score': 0.06816241145133972},
#   {'label': 'joy', 'score': 0.04794280603528023},
#   {'label': 'anger', 'score': 0.009156368672847748},
#   {'label': 'disgust', 'score': 0.002628478454425931},
#   {'label': 'sadness', 'score': 0.0021221672650426626}],
#  [{'label': 'neutral', 'score': 0.4493703842163086},
#   {'label': 'disgust', 'score': 0.27359122037887573},
#   {'label': 'joy', 'score': 0.10908333957195282},
#   {'label': 'sadness', 'score': 0.09362752735614777},
#   {'label': 'anger', 'score': 0.040478311479091644},
#   {'label': 'surprise', 'score': 0.02697012946009636},
#   {'label': 'fear', 'score': 0.006879054941236973}],
#  [{'label': 'neutral', 'score': 0.6462147235870361},
#   {'label': 'sadness', 'score': 0.24273446202278137},
#   {'label': 'disgust', 'score': 0.04342271015048027},
#   {'label': 'surprise', 'score': 0.028300544247031212},
#   {'label': 'joy', 'score': 0.014211485162377357},
#   {'label': 'fear', 'score': 0.014084108173847198},
#   {'label': 'anger', 'score': 0.011031895875930786}],
#  [{'label': 'fear', 'score': 0.928168535232544},
#   {'label': 'anger', 'score': 0.0321907214820385},
#   {'label': 'neutral', 'score': 0.012808626517653465},
#   {'label': 'sadness', 'score': 0.008756839670240879},
#   {'label': 'surprise', 'score': 0.008597870357334614},
#   {'label': 'disgust', 'score': 0.008431773632764816},
#   {'label': 'joy', 'score': 0.0010455811861902475}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104142017662525},
#   {'label': 'disgust', 'score': 0.00648059556260705},
#   {'label': 'fear', 'score': 0.005393985193222761},
#   {'label': 'surprise', 'score': 0.002286937553435564},
#   {'label': 'anger', 'score': 0.0018428885377943516},
#   {'label': 'joy', 'score': 0.0017338788602501154}],
#  [{'label': 'joy', 'score': 0.932797908782959},
#   {'label': 'disgust', 'score': 0.03771715238690376},
#   {'label': 'neutral', 'score': 0.01589186117053032},
#   {'label': 'sadness', 'score': 0.006444504950195551},
#   {'label': 'anger', 'score': 0.00502497935667634},
#   {'label': 'surprise', 'score': 0.0015812070341780782},
#   {'label': 'fear', 'score': 0.0005423061084002256}],
#  [{'label': 'joy', 'score': 0.652871310710907},
#   {'label': 'neutral', 'score': 0.25427427887916565},
#   {'label': 'surprise', 'score': 0.06808299571275711},
#   {'label': 'sadness', 'score': 0.009908992797136307},
#   {'label': 'disgust', 'score': 0.00651220278814435},
#   {'label': 'anger', 'score': 0.004821298643946648},
#   {'label': 'fear', 'score': 0.0035290131345391273}],
#  [{'label': 'neutral', 'score': 0.5494758486747742},
#   {'label': 'sadness', 'score': 0.11169032752513885},
#   {'label': 'disgust', 'score': 0.10400691628456116},
#   {'label': 'surprise', 'score': 0.0787656232714653},
#   {'label': 'anger', 'score': 0.06413383036851883},
#   {'label': 'fear', 'score': 0.05136294662952423},
#   {'label': 'joy', 'score': 0.04056455194950104}]]

# %%
sorted(predictions[0], key=lambda x: x["label"])
# Out:
# [{'label': 'anger', 'score': 0.009156368672847748},
#  {'label': 'disgust', 'score': 0.002628478454425931},
#  {'label': 'fear', 'score': 0.06816241145133972},
#  {'label': 'joy', 'score': 0.04794280603528023},
#  {'label': 'neutral', 'score': 0.14038589596748352},
#  {'label': 'sadness', 'score': 0.0021221672650426626},
#  {'label': 'surprise', 'score': 0.7296019196510315}]

# %%
import numpy as np

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x["label"])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]["score"])
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])

# %%
emotion_scores
# Out:
# {'anger': [np.float64(0.06413383036851883),
#   np.float64(0.612618625164032),
#   np.float64(0.06413383036851883),
#   np.float64(0.3514843285083771),
#   np.float64(0.0814124122262001),
#   np.float64(0.23222504556179047),
#   np.float64(0.5381845831871033),
#   np.float64(0.06413383036851883),
#   np.float64(0.3006700277328491),
#   np.float64(0.06413383036851883)],
#  'disgust': [np.float64(0.27359122037887573),
#   np.float64(0.3482871949672699),
#   np.float64(0.10400691628456116),
#   np.float64(0.15072225034236908),
#   np.float64(0.1844959408044815),
#   np.float64(0.7271746397018433),
#   np.float64(0.15585485100746155),
#   np.float64(0.10400691628456116),
#   np.float64(0.279481440782547),
#   np.float64(0.17792613804340363)],
#  'fear': [np.float64(0.928168535232544),
#   np.float64(0.9425278306007385),
#   np.float64(0.9723208546638489),
#   np.float64(0.36070626974105835),
#   np.float64(0.09504339843988419),
#   np.float64(0.05136294662952423),
#   np.float64(0.747427761554718),
#   np.float64(0.4044976532459259),
#   np.float64(0.9155241250991821),
#   np.float64(0.05136294662952423)],
#  'joy': [np.float64(0.932797908782959),
#   np.float64(0.7044221758842468),
#   np.float64(0.7672376036643982),
#   np.float64(0.2518818974494934),
#   np.float64(0.04056455194950104),
#   np.float64(0.04337591305375099),
#   np.float64(0.8725650906562805),
#   np.float64(0.04056455194950104),
#   np.float64(0.04056455194950104),
#   np.float64(0.04056455194950104)],
#  'sadness': [np.float64(0.6462147235870361),
#   np.float64(0.8879396915435791),
#   np.float64(0.5494758486747742),
#   np.float64(0.7326855659484863),
#   np.float64(0.884389340877533),
#   np.float64(0.6213918328285217),
#   np.float64(0.7121938467025757),
#   np.float64(0.5494758486747742),
#   np.float64(0.8402890563011169),
#   np.float64(0.8603722453117371)],
#  'surprise': [np.float64(0.9671575427055359),
#   np.float64(0.11169032752513885),
#   np.float64(0.11169032752513885),
#   np.float64(0.11169032752513885),
#   np.float64(0.4758811891078949),
#   np.float64(0.11169032752513885),
#   np.float64(0.40799927711486816),
#   np.float64(0.8202835917472839),
#   np.float64(0.3544608950614929),
#   np.float64(0.11169032752513885)],
#  'neutral': [np.float64(0.7296019196510315),
#   np.float64(0.2525458335876465),
#   np.float64(0.0787656232714653),
#   np.float64(0.0787656232714653),
#   np.float64(0.0787656232714653),
#   np.float64(0.2719033658504486),
#   np.float64(0.0787656232714653),
#   np.float64(0.23448684811592102),
#   np.float64(0.13561415672302246),
#   np.float64(0.0787656232714653)]}

# %%
from tqdm import tqdm

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5197/5197 [05:25<00:00, 15.96it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn

# %%
emotions_df
# Out:
#          anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0     0.064134  0.273591  0.928169  0.932798  0.646215  0.967158  0.729602
# 1     0.612619  0.348287  0.942528  0.704422  0.887940  0.111690  0.252546
# 2     0.064134  0.104007  0.972321  0.767238  0.549476  0.111690  0.078766
# 3     0.351484  0.150722  0.360706  0.251882  0.732686  0.111690  0.078766
# 4     0.081412  0.184496  0.095043  0.040565  0.884389  0.475881  0.078766
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148208  0.030643  0.919165  0.255171  0.853721  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339217  0.947779  0.375754  0.066685  0.057625
# 5195  0.064134  0.104007  0.459271  0.759456  0.951104  0.368110  0.078766
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078766
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# 2     9780006178736
# 3     9780006280897
# 4     9780006280934
# ...             ...
# 5192  9788172235222
# 5193  9788173031014
# 5194  9788179921623
# 5195  9788185300535
# 5196  9789027712059
#
# [5197 rows x 8 columns]

# %%
books = pd.merge(books, emotions_df, on = "isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.93      512.0  ...
# 3               4.15      170.0  ...
# 4               4.09      176.0  ...
# ...              ...        ...  ...
# 5192            2.93      324.0  ...
# 5193            3.70      175.0  ...
# 5194            3.82      198.0  ...
# 5195            4.51      531.0  ...
# 5196            0.00      210.0  ...
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   sadness  surprise   neutral
# 0     0.064134  0.273591  0.928169  0.932798  0.646215  0.967158  0.729602
# 1     0.612619  0.348287  0.942528  0.704422  0.887940  0.111690  0.252546
# 2     0.064134  0.104007  0.972321  0.767238  0.549476  0.111690  0.078766
# 3     0.351484  0.150722  0.360706  0.251882  0.732686  0.111690  0.078766
# 4     0.081412  0.184496  0.095043  0.040565  0.884389  0.475881  0.078766
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148208  0.030643  0.919165  0.255171  0.853721  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339217  0.947779  0.375754  0.066685  0.057625
# 5195  0.064134  0.104007  0.459271  0.759456  0.951104  0.368110  0.078766
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078766
#
# [5197 rows x 21 columns]

# %%
books.to_csv("books_with_emotions.csv", index = False)
